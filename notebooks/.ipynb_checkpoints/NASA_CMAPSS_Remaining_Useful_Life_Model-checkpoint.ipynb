# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from sklearn.model_selection import train_test_split

# %%
data_train = pd.read_csv('train_FD001.txt', sep=' ', header=None)
data_test = pd.read_csv('test_FD001.txt', sep=' ', header=None)
data_train.head()
# Out:
#    0   1         2         3         4         5         6    7         8   \
# 0   1   1  0.459770  0.166667  0.168712  0.414463  0.326164  1.0  0.698582
# 1   1   2  0.609195  0.250000  0.285714  0.532547  0.328845  1.0  0.670103
# 2   1   3  0.252874  0.750000  0.360656  0.419199  0.351630  1.0  0.752515
# 3   1   4  0.540230  0.500000  0.335366  0.228752  0.277007  1.0  0.763941
# 4   1   5  0.390805  0.333333  0.337423  0.254154  0.426058  1.0  0.634752
#
#          9         10        11        12        13        14        15  \
# 0  0.254237  0.097450  0.371257  0.621978  0.205882  0.181029  0.387807
# 1  0.311111  0.100487  0.401274  0.764988  0.304348  0.178997  0.411312
# 2  0.254237  0.150919  0.203947  0.832947  0.174603  0.150922  0.353448
# 3  0.307692  0.116109  0.161677  0.889126  0.292308  0.168236  0.149625
# 4  0.254237  0.139227  0.257485  0.738462  0.235294  0.154889  0.429721
#
#          16        17        18  19
# 0  0.300000  0.771930  0.758820   3
# 1  0.272727  0.672000  0.730050   1
# 2  0.111111  0.654867  0.614064   2
# 3  0.363636  0.573643  0.644570   0
# 4  0.400000  0.631579  0.737710   3

# %%
data_train.rename(columns={0: 'ID', 1: 'Cycles', 19:"Clustering"}, inplace=True)
data_train["RUL"] = data_train.groupby("ID")["Cycles"].transform(lambda x: x.max() - x)
data_test.rename(columns={0: 'ID', 1: 'Cycles', 19:"Clustering"}, inplace=True)
data_test["RUL"] = data_test.groupby("ID")["Cycles"].transform(lambda x: x.max() - x)
data_train.head()
# Out:
#    ID  Cycles         2         3         4         5         6    7  \
# 0   1       1  0.459770  0.166667  0.168712  0.414463  0.326164  1.0
# 1   1       2  0.609195  0.250000  0.285714  0.532547  0.328845  1.0
# 2   1       3  0.252874  0.750000  0.360656  0.419199  0.351630  1.0
# 3   1       4  0.540230  0.500000  0.335366  0.228752  0.277007  1.0
# 4   1       5  0.390805  0.333333  0.337423  0.254154  0.426058  1.0
#
#           8         9  ...        11        12        13        14        15  \
# 0  0.698582  0.254237  ...  0.371257  0.621978  0.205882  0.181029  0.387807
# 1  0.670103  0.311111  ...  0.401274  0.764988  0.304348  0.178997  0.411312
# 2  0.752515  0.254237  ...  0.203947  0.832947  0.174603  0.150922  0.353448
# 3  0.763941  0.307692  ...  0.161677  0.889126  0.292308  0.168236  0.149625
# 4  0.634752  0.254237  ...  0.257485  0.738462  0.235294  0.154889  0.429721
#
#          16        17        18  Clustering  RUL
# 0  0.300000  0.771930  0.758820           3  191
# 1  0.272727  0.672000  0.730050           1  190
# 2  0.111111  0.654867  0.614064           2  189
# 3  0.363636  0.573643  0.644570           0  188
# 4  0.400000  0.631579  0.737710           3  187
#
# [5 rows x 21 columns]

# %%
window_size = 30
def create_Sets(data_train, window_size):
    X = []
    Y = []
    # Agrupamos por ID de motor
    for j, group in data_train.groupby("ID"):
        group = group.sort_values("Cycles")
        features = group.iloc[:, 2:-1].values  # columnas 2 hasta penúltima (sin ID, Cycles, ni RUL)
        rul_values = group["RUL"].values

        if len(group) >= window_size:
            for i in range(len(group) - window_size + 1):
                X.append(features[i:i + window_size])
                Y.append(rul_values[i + window_size - 1])
        else:
            print(f"Warning: Unit {j} has less than {window_size} cycles")
    X = np.array(X)
    Y = np.array(Y)
    return torch.tensor(X, dtype=torch.float32), torch.tensor(Y[:, None], dtype=torch.float32)
X_train, Y_train = create_Sets(data_train, window_size)
X_test, Y_test = create_Sets(data_test, window_size)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2)

# %%
Y_train.shape
# Out:
# torch.Size([14184, 1])

# %%
class Predictions(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=18, hidden_size=50, num_layers=1, batch_first=True)
        self.dropout = nn.Dropout(0.2)  # 20% de desconexión
        self.linear = nn.Linear(50, 1)
        self.relu = nn.ReLU()
    def forward(self, x):
        x, _ = self.lstm(x)
        # extract only the last time step
        x = x[:, -1, :]
        x = self.dropout(x)
        x = self.linear(x)
        x = self.relu(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)

model = Predictions().to(device)
optimizer = torch.optim.AdamW(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5, verbose=True)
loss_fn = nn.MSELoss()

X_train = X_train.to(device)
Y_train = Y_train.to(device)
X_test = X_test.to(device)
Y_test = Y_test.to(device)
X_val = X_val.to(device)
Y_val = Y_val.to(device)

loader = data.DataLoader(data.TensorDataset(X_train, Y_train), shuffle=True, batch_size=20)

n_epochs = 50
for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train)
        train_rmse = torch.sqrt(loss_fn(y_pred, Y_train)).item()
        y_pred = model(X_val)
        val_rmse = torch.sqrt(loss_fn(y_pred, Y_val)).item()
    print("Epoch %d: train RMSE %.4f, val RMSE %.4f" % (epoch, train_rmse, val_rmse))
# Out:
# Usando dispositivo: cuda
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0: train RMSE 84.2586, val RMSE 82.6703
# Epoch 1: train RMSE 69.9848, val RMSE 68.5966
# Epoch 2: train RMSE 63.9967, val RMSE 62.8702
# Epoch 3: train RMSE 62.4026, val RMSE 61.4680
# Epoch 4: train RMSE 47.4588, val RMSE 46.4036
# Epoch 5: train RMSE 41.4787, val RMSE 40.7225
# Epoch 6: train RMSE 38.1393, val RMSE 37.5564
# Epoch 7: train RMSE 35.8116, val RMSE 35.4941
# Epoch 8: train RMSE 33.5705, val RMSE 32.8864
# Epoch 9: train RMSE 32.8005, val RMSE 32.2178
# Epoch 10: train RMSE 32.9665, val RMSE 32.6448
# Epoch 11: train RMSE 31.8549, val RMSE 31.4407
# Epoch 12: train RMSE 32.9065, val RMSE 32.0877
# Epoch 13: train RMSE 33.5229, val RMSE 33.0862
# Epoch 14: train RMSE 31.1461, val RMSE 30.7487
# Epoch 15: train RMSE 31.3112, val RMSE 30.7240
# Epoch 16: train RMSE 32.3263, val RMSE 31.6369
# Epoch 17: train RMSE 31.0449, val RMSE 30.4705
# Epoch 18: train RMSE 31.1789, val RMSE 30.8456
# Epoch 19: train RMSE 32.7552, val RMSE 31.9055
# Epoch 20: train RMSE 31.3935, val RMSE 31.1049
# Epoch 21: train RMSE 30.3920, val RMSE 30.2180
# Epoch 22: train RMSE 30.2354, val RMSE 30.0552
# Epoch 23: train RMSE 31.8603, val RMSE 32.0330
# Epoch 24: train RMSE 30.2798, val RMSE 30.2521
# Epoch 25: train RMSE 31.0581, val RMSE 31.0933
# Epoch 26: train RMSE 29.8951, val RMSE 29.5041
# Epoch 27: train RMSE 30.2728, val RMSE 29.9256
# Epoch 28: train RMSE 31.0631, val RMSE 31.0382
# Epoch 29: train RMSE 29.8588, val RMSE 29.4513
# Epoch 30: train RMSE 29.6658, val RMSE 29.4047
# Epoch 31: train RMSE 31.3343, val RMSE 30.6180
# Epoch 32: train RMSE 30.0875, val RMSE 29.7880
# Epoch 33: train RMSE 29.8120, val RMSE 29.3678
# Epoch 34: train RMSE 30.4367, val RMSE 29.8304
# Epoch 35: train RMSE 29.3565, val RMSE 29.1293
# Epoch 36: train RMSE 30.4315, val RMSE 30.0280
# Epoch 37: train RMSE 30.8823, val RMSE 30.2249
# Epoch 38: train RMSE 30.4889, val RMSE 29.9654
# Epoch 39: train RMSE 30.9202, val RMSE 30.3758
# Epoch 40: train RMSE 28.8499, val RMSE 28.7415
# Epoch 41: train RMSE 28.8140, val RMSE 28.6871
# Epoch 42: train RMSE 29.4835, val RMSE 29.0851
# Epoch 43: train RMSE 30.0550, val RMSE 29.6815
# Epoch 44: train RMSE 29.0665, val RMSE 29.0060
# Epoch 45: train RMSE 33.9980, val RMSE 32.9556
# Epoch 46: train RMSE 28.5785, val RMSE 28.4174
# Epoch 47: train RMSE 29.1897, val RMSE 28.8247
# Epoch 48: train RMSE 29.3707, val RMSE 29.3128
# Epoch 49: train RMSE 28.2057, val RMSE 28.0839

# %%
t = len(Y_test)
model.eval()
with torch.no_grad():
    y_pred = model(X_test).cpu().numpy()
    plt.plot(np.arange(t), Y_test.cpu().numpy(), 'b', label='True Value')
    plt.plot(np.arange(t), y_pred, 'r', label='Prediction')
    plt.legend(loc='upper left')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = model(X_test).cpu().detach().numpy().flatten()
y_true = Y_test.cpu().detach().numpy().flatten()

rmse =np.sqrt( mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
# Out:
# RMSE: 49.97
# MAE: 38.54

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = model(X_val).cpu().detach().numpy().flatten()
y_true = Y_val.cpu().detach().numpy().flatten()

rmse =np.sqrt( mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
# Out:
# RMSE: 28.08
# MAE: 18.77

# %%
data_test["RUL"].mean()
# Out:
# np.float64(75.83651496640195)

# %%
data_train["RUL"].max()
# Out:
# 361
